# %%
import pandas as pd

# %%
data = pd.read_csv( '../Datasets/data-filter.csv' )
data
# Out:
#                id             date     price  bedrooms  bathrooms  floors  \
# 0      7129300520  20141013T000000  221900.0         3       1.00     1.0
# 1      6414100192  20141209T000000  538000.0         3       2.25     2.0
# 2      5631500400  20150225T000000  180000.0         2       1.00     1.0
# 3      2487200875  20141209T000000  604000.0         4       3.00     1.0
# 4      1954400510  20150218T000000  510000.0         3       2.00     1.0
# ...           ...              ...       ...       ...        ...     ...
# 21607   263000018  20140521T000000  360000.0         3       2.50     3.0
# 21608  6600060120  20150223T000000  400000.0         4       2.50     2.0
# 21609  1523300141  20140623T000000  402101.0         2       0.75     2.0
# 21610   291310100  20150116T000000  400000.0         3       2.50     2.0
# 21611  1523300157  20141015T000000  325000.0         2       0.75     2.0
#
#        waterfront  condition  yr_built  yr_renovated  zipcode      lat  \
# ...

# %%
data.dtypes
# Out:
# id                       int64
# date            datetime64[ns]
# price                  float64
# bedrooms                 int64
# bathrooms              float64
# floors                 float64
# waterfront               int64
# condition                int64
# yr_built                 int64
# yr_renovated             int64
# zipcode                  int64
# lat                    float64
# long                   float64
# dtype: object

# %%
data['date'] = pd.to_datetime( data['date'] )

# %%
data
# Out:
#                id       date     price  bedrooms  bathrooms  floors  \
# 0      7129300520 2014-10-13  221900.0         3       1.00     1.0
# 1      6414100192 2014-12-09  538000.0         3       2.25     2.0
# 2      5631500400 2015-02-25  180000.0         2       1.00     1.0
# 3      2487200875 2014-12-09  604000.0         4       3.00     1.0
# 4      1954400510 2015-02-18  510000.0         3       2.00     1.0
# ...           ...        ...       ...       ...        ...     ...
# 21607   263000018 2014-05-21  360000.0         3       2.50     3.0
# 21608  6600060120 2015-02-23  400000.0         4       2.50     2.0
# 21609  1523300141 2014-06-23  402101.0         2       0.75     2.0
# 21610   291310100 2015-01-16  400000.0         3       2.50     2.0
# 21611  1523300157 2014-10-15  325000.0         2       0.75     2.0
#
#        waterfront  condition  yr_built  yr_renovated  zipcode      lat  \
# 0               0          3      1955             0    98178  47.5112
# ...
